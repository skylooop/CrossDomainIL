# %%
import numpy as np
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.ppo import MlpPolicy

from imitation.algorithms.adversarial.gail import GAIL
from imitation.data import rollout
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.policies.serialize import load_policy
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm
from imitation.util.util import make_vec_env

SEED = 42
# Out:
# 2024-06-28 05:58:17.194209: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-28 05:58:17.747107: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
env = make_vec_env(
    "seals:seals/CartPole-v0",
    rng=np.random.default_rng(SEED),
    n_envs=8,
    post_wrappers=[lambda env, _: RolloutInfoWrapper(env)],  # to compute rollouts
)
expert = load_policy(
    "ppo-huggingface",
    organization="HumanCompatibleAI",
    env_name="seals-CartPole-v0",
    venv=env,
)

rollouts = rollout.rollout(
    expert,
    env,
    rollout.make_sample_until(min_timesteps=None, min_episodes=60),
    rng=np.random.default_rng(SEED),
)

learner = PPO(
    env=env,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0004,
    gamma=0.95,
    n_epochs=5,
    seed=SEED,
)
reward_net = BasicRewardNet(
    observation_space=env.observation_space,
    action_space=env.action_space,
    normalize_input_layer=RunningNorm,
)

gail_trainer = GAIL(
    demonstrations=rollouts,
    demo_batch_size=180,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=8,
    venv=env,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
# evaluate the learner before training
env.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True,
)

# train the learner and evaluate again
gail_trainer.train(200_000)  # Train for 800_000 steps to match expert.
env.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True,
)

print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))
# Out:
# round:   0%|          | 0/12 [00:00<?, ?it/s]
# ------------------------------------------
# | raw/                        |          |
# |    gen/rollout/ep_len_mean  | 500      |
# |    gen/rollout/ep_rew_mean  | 34.4     |
# |    gen/time/fps             | 5466     |
# |    gen/time/iterations      | 1        |
# |    gen/time/time_elapsed    | 2        |
# |    gen/time/total_timesteps | 16384    |
# ------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.685    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.683    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.681    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.679    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.675    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.678    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 34.4     |
# |    gen/time/fps                     | 5.47e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 1.64e+04 |
# |    gen/train/approx_kl              | 0.00699  |
# |    gen/train/clip_fraction          | 0.0338   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.687   |
# |    gen/train/explained_variance     | 0.0555   |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0315   |
# |    gen/train/n_updates              | 5        |
# |    gen/train/policy_gradient_loss   | -0.00158 |
# |    gen/train/value_loss             | 4.7      |
# --------------------------------------------------
# round:   8%|▊         | 1/12 [00:06<01:07,  6.14s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 35.3        |
# |    gen/rollout/ep_rew_wrapped_mean | 270         |
# |    gen/time/fps                    | 5444        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 3           |
# |    gen/time/total_timesteps        | 32768       |
# |    gen/train/approx_kl             | 0.006985818 |
# |    gen/train/clip_fraction         | 0.0338      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.687      |
# |    gen/train/explained_variance    | 0.0555      |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0315      |
# |    gen/train/n_updates             | 5           |
# |    gen/train/policy_gradient_loss  | -0.00158    |
# |    gen/train/value_loss            | 4.7         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.679    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.675    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 35.3     |
# |    gen/rollout/ep_rew_wrapped_mean  | 270      |
# |    gen/time/fps                     | 5.44e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 3        |
# |    gen/time/total_timesteps         | 3.28e+04 |
# |    gen/train/approx_kl              | 0.00871  |
# |    gen/train/clip_fraction          | 0.0647   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.677   |
# |    gen/train/explained_variance     | 0.728    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0786   |
# |    gen/train/n_updates              | 10       |
# |    gen/train/policy_gradient_loss   | -0.00238 |
# |    gen/train/value_loss             | 0.26     |
# --------------------------------------------------
# round:  17%|█▋        | 2/12 [00:12<01:01,  6.14s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 33.2        |
# |    gen/rollout/ep_rew_wrapped_mean | 284         |
# |    gen/time/fps                    | 5634        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 49152       |
# |    gen/train/approx_kl             | 0.008708343 |
# |    gen/train/clip_fraction         | 0.0647      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.677      |
# |    gen/train/explained_variance    | 0.728       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0786      |
# |    gen/train/n_updates             | 10          |
# |    gen/train/policy_gradient_loss  | -0.00238    |
# |    gen/train/value_loss            | 0.26        |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.673    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.67     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.67     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.668    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.667    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.666    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.663    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.669    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 33.2     |
# |    gen/rollout/ep_rew_wrapped_mean  | 284      |
# |    gen/time/fps                     | 5.63e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 4.92e+04 |
# |    gen/train/approx_kl              | 0.00889  |
# |    gen/train/clip_fraction          | 0.0534   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.677   |
# |    gen/train/explained_variance     | 0.883    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0317   |
# |    gen/train/n_updates              | 15       |
# |    gen/train/policy_gradient_loss   | -0.00414 |
# |    gen/train/value_loss             | 0.0468   |
# --------------------------------------------------
# round:  25%|██▌       | 3/12 [00:18<00:54,  6.09s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 35.9        |
# |    gen/rollout/ep_rew_wrapped_mean | 278         |
# |    gen/time/fps                    | 5577        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 65536       |
# |    gen/train/approx_kl             | 0.008885191 |
# |    gen/train/clip_fraction         | 0.0534      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.677      |
# |    gen/train/explained_variance    | 0.883       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0317      |
# |    gen/train/n_updates             | 15          |
# |    gen/train/policy_gradient_loss  | -0.00414    |
# |    gen/train/value_loss            | 0.0468      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.653    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.649    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.649    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.643    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.495    |
# |    disc/disc_acc_expert             | 0.00195  |
# |    disc/disc_acc_gen                | 0.988    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.636    |
# |    disc/disc_proportion_expert_pred | 0.00684  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.493    |
# |    disc/disc_acc_expert             | 0.00977  |
# |    disc/disc_acc_gen                | 0.976    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.639    |
# |    disc/disc_proportion_expert_pred | 0.0171   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.498    |
# |    disc/disc_acc_expert             | 0.00146  |
# |    disc/disc_acc_gen                | 0.995    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.644    |
# |    disc/disc_proportion_expert_pred | 0.00299  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 35.9     |
# |    gen/rollout/ep_rew_wrapped_mean  | 278      |
# |    gen/time/fps                     | 5.58e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 6.55e+04 |
# |    gen/train/approx_kl              | 0.0132   |
# |    gen/train/clip_fraction          | 0.131    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.662   |
# |    gen/train/explained_variance     | 0.936    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.00448 |
# |    gen/train/n_updates              | 20       |
# |    gen/train/policy_gradient_loss   | -0.0133  |
# |    gen/train/value_loss             | 0.0171   |
# --------------------------------------------------
# round:  33%|███▎      | 4/12 [00:24<00:48,  6.03s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_len_mean         | 500        |
# |    gen/rollout/ep_rew_mean         | 40         |
# |    gen/rollout/ep_rew_wrapped_mean | 276        |
# |    gen/time/fps                    | 5595       |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 2          |
# |    gen/time/total_timesteps        | 81920      |
# |    gen/train/approx_kl             | 0.01323979 |
# |    gen/train/clip_fraction         | 0.131      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -0.662     |
# |    gen/train/explained_variance    | 0.936      |
# |    gen/train/learning_rate         | 0.0004     |
# |    gen/train/loss                  | -0.00448   |
# |    gen/train/n_updates             | 20         |
# |    gen/train/policy_gradient_loss  | -0.0133    |
# |    gen/train/value_loss            | 0.0171     |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.484    |
# |    disc/disc_acc_expert             | 0.0459   |
# |    disc/disc_acc_gen                | 0.922    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.649    |
# |    disc/disc_proportion_expert_pred | 0.062    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.526    |
# |    disc/disc_acc_expert             | 0.144    |
# |    disc/disc_acc_gen                | 0.909    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0.117    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.611    |
# |    disc/disc_acc_expert             | 0.34     |
# |    disc/disc_acc_gen                | 0.882    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.229    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.661    |
# |    disc/disc_acc_expert             | 0.459    |
# |    disc/disc_acc_gen                | 0.863    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0.298    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.675    |
# |    disc/disc_acc_expert             | 0.478    |
# |    disc/disc_acc_gen                | 0.873    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0.302    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.691    |
# |    disc/disc_acc_expert             | 0.509    |
# |    disc/disc_acc_gen                | 0.874    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.639    |
# |    disc/disc_proportion_expert_pred | 0.317    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.676    |
# |    disc/disc_acc_expert             | 0.499    |
# |    disc/disc_acc_gen                | 0.854    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.637    |
# |    disc/disc_proportion_expert_pred | 0.323    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.681    |
# |    disc/disc_acc_expert             | 0.506    |
# |    disc/disc_acc_gen                | 0.856    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.634    |
# |    disc/disc_proportion_expert_pred | 0.325    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.626    |
# |    disc/disc_acc_expert             | 0.372    |
# |    disc/disc_acc_gen                | 0.879    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.643    |
# |    disc/disc_proportion_expert_pred | 0.247    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 40       |
# |    gen/rollout/ep_rew_wrapped_mean  | 276      |
# |    gen/time/fps                     | 5.6e+03  |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 8.19e+04 |
# |    gen/train/approx_kl              | 0.013    |
# |    gen/train/clip_fraction          | 0.158    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.647   |
# |    gen/train/explained_variance     | 0.912    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.0258  |
# |    gen/train/n_updates              | 25       |
# |    gen/train/policy_gradient_loss   | -0.0157  |
# |    gen/train/value_loss             | 0.0174   |
# --------------------------------------------------
# round:  42%|████▏     | 5/12 [00:30<00:42,  6.05s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 47.5        |
# |    gen/rollout/ep_rew_wrapped_mean | 273         |
# |    gen/time/fps                    | 5560        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 98304       |
# |    gen/train/approx_kl             | 0.013039661 |
# |    gen/train/clip_fraction         | 0.158       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.647      |
# |    gen/train/explained_variance    | 0.912       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.0258     |
# |    gen/train/n_updates             | 25          |
# |    gen/train/policy_gradient_loss  | -0.0157     |
# |    gen/train/value_loss            | 0.0174      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.653    |
# |    disc/disc_acc_expert             | 0.511    |
# |    disc/disc_acc_gen                | 0.795    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.644    |
# |    disc/disc_proportion_expert_pred | 0.358    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.66     |
# |    disc/disc_acc_expert             | 0.526    |
# |    disc/disc_acc_gen                | 0.794    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.643    |
# |    disc/disc_proportion_expert_pred | 0.366    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.634    |
# |    disc/disc_acc_expert             | 0.497    |
# |    disc/disc_acc_gen                | 0.771    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0.363    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.626    |
# |    disc/disc_acc_expert             | 0.487    |
# |    disc/disc_acc_gen                | 0.765    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0.361    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.654    |
# |    disc/disc_acc_expert             | 0.514    |
# |    disc/disc_acc_gen                | 0.795    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.638    |
# |    disc/disc_proportion_expert_pred | 0.359    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.641    |
# |    disc/disc_acc_expert             | 0.516    |
# |    disc/disc_acc_gen                | 0.766    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.637    |
# |    disc/disc_proportion_expert_pred | 0.375    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.623    |
# |    disc/disc_acc_expert             | 0.486    |
# |    disc/disc_acc_gen                | 0.759    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.635    |
# |    disc/disc_proportion_expert_pred | 0.364    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.673    |
# |    disc/disc_acc_expert             | 0.573    |
# |    disc/disc_acc_gen                | 0.772    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.637    |
# |    disc/disc_proportion_expert_pred | 0.4      |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.645    |
# |    disc/disc_acc_expert             | 0.514    |
# |    disc/disc_acc_gen                | 0.777    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.368    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 47.5     |
# |    gen/rollout/ep_rew_wrapped_mean  | 273      |
# |    gen/time/fps                     | 5.56e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 9.83e+04 |
# |    gen/train/approx_kl              | 0.0154   |
# |    gen/train/clip_fraction          | 0.15     |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.597   |
# |    gen/train/explained_variance     | 0.919    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.00624  |
# |    gen/train/n_updates              | 30       |
# |    gen/train/policy_gradient_loss   | -0.0108  |
# |    gen/train/value_loss             | 0.0179   |
# --------------------------------------------------
# round:  50%|█████     | 6/12 [00:36<00:36,  6.07s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 54.3        |
# |    gen/rollout/ep_rew_wrapped_mean | 278         |
# |    gen/time/fps                    | 5260        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 3           |
# |    gen/time/total_timesteps        | 114688      |
# |    gen/train/approx_kl             | 0.015362133 |
# |    gen/train/clip_fraction         | 0.15        |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.597      |
# |    gen/train/explained_variance    | 0.919       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.00624     |
# |    gen/train/n_updates             | 30          |
# |    gen/train/policy_gradient_loss  | -0.0108     |
# |    gen/train/value_loss            | 0.0179      |
# ...
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 500          |
# |    gen/rollout/ep_rew_mean         | 85.2         |
# |    gen/rollout/ep_rew_wrapped_mean | 274          |
# |    gen/time/fps                    | 5557         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 180224       |
# |    gen/train/approx_kl             | 0.0068827113 |
# |    gen/train/clip_fraction         | 0.0802       |
# |    gen/train/clip_range            | 0.2          |
# |    gen/train/entropy_loss          | -0.599       |
# |    gen/train/explained_variance    | 0.96         |
# |    gen/train/learning_rate         | 0.0004       |
# |    gen/train/loss                  | 0.0102       |
# |    gen/train/n_updates             | 50           |
# |    gen/train/policy_gradient_loss  | -0.00378     |
# |    gen/train/value_loss            | 0.0321       |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.735    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.471    |
# |    disc/disc_entropy                | 0.671    |
# |    disc/disc_loss                   | 0.609    |
# |    disc/disc_proportion_expert_pred | 0.765    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.745    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.489    |
# |    disc/disc_entropy                | 0.667    |
# |    disc/disc_loss                   | 0.599    |
# |    disc/disc_proportion_expert_pred | 0.755    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.751    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.502    |
# |    disc/disc_entropy                | 0.668    |
# |    disc/disc_loss                   | 0.6      |
# |    disc/disc_proportion_expert_pred | 0.749    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.737    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.474    |
# |    disc/disc_entropy                | 0.666    |
# |    disc/disc_loss                   | 0.601    |
# |    disc/disc_proportion_expert_pred | 0.763    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.744    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.488    |
# |    disc/disc_entropy                | 0.663    |
# |    disc/disc_loss                   | 0.592    |
# |    disc/disc_proportion_expert_pred | 0.756    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.749    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.498    |
# |    disc/disc_entropy                | 0.665    |
# |    disc/disc_loss                   | 0.596    |
# |    disc/disc_proportion_expert_pred | 0.751    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.752    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.504    |
# |    disc/disc_entropy                | 0.662    |
# |    disc/disc_loss                   | 0.59     |
# |    disc/disc_proportion_expert_pred | 0.748    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.752    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.504    |
# |    disc/disc_entropy                | 0.66     |
# |    disc/disc_loss                   | 0.589    |
# |    disc/disc_proportion_expert_pred | 0.748    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.746    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.491    |
# |    disc/disc_entropy                | 0.665    |
# |    disc/disc_loss                   | 0.597    |
# |    disc/disc_proportion_expert_pred | 0.754    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 85.2     |
# |    gen/rollout/ep_rew_wrapped_mean  | 274      |
# |    gen/time/fps                     | 5.56e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 1.8e+05  |
# |    gen/train/approx_kl              | 0.00821  |
# |    gen/train/clip_fraction          | 0.0982   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.601   |
# |    gen/train/explained_variance     | 0.935    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0091   |
# |    gen/train/n_updates              | 55       |
# |    gen/train/policy_gradient_loss   | -0.00593 |
# |    gen/train/value_loss             | 0.0442   |
# --------------------------------------------------
# round:  92%|█████████▏| 11/12 [01:06<00:06,  6.03s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 91.3        |
# |    gen/rollout/ep_rew_wrapped_mean | 272         |
# |    gen/time/fps                    | 5564        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 196608      |
# |    gen/train/approx_kl             | 0.008205008 |
# |    gen/train/clip_fraction         | 0.0982      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.601      |
# |    gen/train/explained_variance    | 0.935       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0091      |
# |    gen/train/n_updates             | 55          |
# |    gen/train/policy_gradient_loss  | -0.00593    |
# |    gen/train/value_loss            | 0.0442      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.546    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0928   |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.678    |
# |    disc/disc_proportion_expert_pred | 0.954    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.555    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.109    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.675    |
# |    disc/disc_proportion_expert_pred | 0.945    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.556    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.111    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.676    |
# |    disc/disc_proportion_expert_pred | 0.944    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.559    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.117    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0.941    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.568    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.136    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.673    |
# |    disc/disc_proportion_expert_pred | 0.932    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.57     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.141    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.671    |
# |    disc/disc_proportion_expert_pred | 0.93     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.567    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.134    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.671    |
# |    disc/disc_proportion_expert_pred | 0.933    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.582    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.163    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.67     |
# |    disc/disc_proportion_expert_pred | 0.918    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.563    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.125    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0.937    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 91.3     |
# |    gen/rollout/ep_rew_wrapped_mean  | 272      |
# |    gen/time/fps                     | 5.56e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 1.97e+05 |
# |    gen/train/approx_kl              | 0.00608  |
# |    gen/train/clip_fraction          | 0.0667   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.576   |
# |    gen/train/explained_variance     | 0.968    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0283   |
# |    gen/train/n_updates              | 60       |
# |    gen/train/policy_gradient_loss   | -0.00421 |
# |    gen/train/value_loss             | 0.0558   |
# --------------------------------------------------
# round: 100%|██████████| 12/12 [01:12<00:00,  6.06s/it]
# mean reward after training: 321.46
# mean reward before training: 102.6

# %%
import datasets
from imitation.data import huggingface_utils

# Download some expert trajectories from the HuggingFace Datasets Hub.
dataset = datasets.load_dataset("HumanCompatibleAI/ppo-Pendulum-v1")

# Convert the dataset to a format usable by the imitation library.
expert_trajectories = huggingface_utils.TrajectoryDatasetSequence(dataset["train"])
# Out:
# Downloading readme:   0%|          | 0.00/536 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/940k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
from imitation.data import rollout

trajectory_stats = rollout.rollout_stats(expert_trajectories)

print(
    f"We have {trajectory_stats['n_traj']} trajectories. "
    f"The average length of each trajectory is {trajectory_stats['len_mean']}. "
    f"The average return of each trajectory is {trajectory_stats['return_mean']}."
)
# Out:
# We have 200 trajectories. The average length of each trajectory is 200.0. The average return of each trajectory is -205.22814517737746.

# %%
expert_trajectories[0].acts.shape
# Out:
# (200, 1)

# %%
venv = make_vec_env(
    "Pendulum-v1",
    rng=np.random.default_rng(seed=SEED),
)

# %%
from stable_baselines3 import sac


learner = sac.SAC(
    env=venv,
    policy="MlpPolicy",
    batch_size=64,
    gamma=0.95,
    seed=SEED,
)
reward_net = BasicRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

gail_trainer = GAIL(
    demonstrations=expert_trajectories,
    demo_batch_size=1024,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=8,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       1 from stable_baselines3 import sac
# ----> 4 learner = sac.SAC(
#       5     env=venv,
#       6     policy=MlpPolicy,
#       7     batch_size=64,
#       8     gamma=0.95,
#       9     seed=SEED,
#      10 )
#      11 reward_net = BasicRewardNet(
#      12     observation_space=venv.observation_space,
#      13     action_space=venv.action_space,
#      14     normalize_input_layer=RunningNorm,
#      15 )
#      17 gail_trainer = GAIL(
#      18     demonstrations=expert_trajectories,
#      19     demo_batch_size=1024,
#    (...)
#      24     reward_net=reward_net,
#      25 )
#
# File ~/anaconda3/envs/icvf/lib/python3.9/site-packages/stable_baselines3/sac/sac.py:157, in SAC.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, ent_coef, target_update_interval, target_entropy, use_sde, sde_sample_freq, use_sde_at_warmup, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#     154 self.ent_coef_optimizer: Optional[th.optim.Adam] = None
#     156 if _init_setup_model:
# --> 157     self._setup_model()
#
# File ~/anaconda3/envs/icvf/lib/python3.9/site-packages/stable_baselines3/sac/sac.py:161, in SAC._setup_model(self)
#     159 def _setup_model(self) -> None:
#     160     super()._setup_model()
# --> 161     self._create_aliases()
#     162     # Running mean and running var
#     163     self.batch_norm_stats = get_parameters_by_name(self.critic, ["running_"])
#
# File ~/anaconda3/envs/icvf/lib/python3.9/site-packages/stable_baselines3/sac/sac.py:195, in SAC._create_aliases(self)
#     194 def _create_aliases(self) -> None:
# --> 195     self.actor = self.policy.actor
#     196     self.critic = self.policy.critic
#     197     self.critic_target = self.policy.critic_target
#
# File ~/anaconda3/envs/icvf/lib/python3.9/site-packages/torch/nn/modules/module.py:1688, in Module.__getattr__(self, name)
#    1686     if name in modules:
#    1687         return modules[name]
# -> 1688 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'ActorCriticPolicy' object has no attribute 'actor'

# %%
learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 100, return_episode_rewards=True,
)

# train the learner and evaluate again
gail_trainer.train(200_000)  # Train for 800_000 steps to match expert.
env.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 100, return_episode_rewards=True,
)

print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))
# Out:
# round:   0%|          | 0/12 [00:00<?, ?it/s]
# -------------------------------------------
# | raw/                        |           |
# |    gen/rollout/ep_len_mean  | 200       |
# |    gen/rollout/ep_rew_mean  | -1.19e+03 |
# |    gen/time/fps             | 6161      |
# |    gen/time/iterations      | 1         |
# |    gen/time/time_elapsed    | 2         |
# |    gen/time/total_timesteps | 16384     |
# -------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.499    |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 0.997    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.708    |
# |    disc/disc_proportion_expert_pred | 0.00146  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.705    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.702    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.7      |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.698    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.695    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.501    |
# |    disc/disc_acc_expert             | 0.00293  |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.693    |
# |    disc/disc_proportion_expert_pred | 0.00146  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.503    |
# |    disc/disc_acc_expert             | 0.00684  |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.69     |
# |    disc/disc_proportion_expert_pred | 0.00342  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.5       |
# |    disc/disc_acc_expert             | 0.00122   |
# |    disc/disc_acc_gen                | 1         |
# |    disc/disc_entropy                | 0.691     |
# |    disc/disc_loss                   | 0.699     |
# |    disc/disc_proportion_expert_pred | 0.000793  |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 1         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 200       |
# |    gen/rollout/ep_rew_mean          | -1.19e+03 |
# |    gen/time/fps                     | 6.16e+03  |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 2         |
# |    gen/time/total_timesteps         | 1.64e+04  |
# |    gen/train/approx_kl              | 0.00212   |
# |    gen/train/clip_fraction          | 0.0177    |
# |    gen/train/clip_range             | 0.2       |
# |    gen/train/entropy_loss           | -1.42     |
# |    gen/train/explained_variance     | -0.012    |
# |    gen/train/learning_rate          | 0.0004    |
# |    gen/train/loss                   | 0.139     |
# |    gen/train/n_updates              | 5         |
# |    gen/train/policy_gradient_loss   | -0.000286 |
# |    gen/train/std                    | 1.01      |
# |    gen/train/value_loss             | 5.45      |
# ---------------------------------------------------
# round:   8%|▊         | 1/12 [00:05<01:02,  5.72s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 200          |
# |    gen/rollout/ep_rew_mean         | -1.23e+03    |
# |    gen/rollout/ep_rew_wrapped_mean | 131          |
# |    gen/time/fps                    | 6182         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 32768        |
# |    gen/train/approx_kl             | 0.0021170615 |
# |    gen/train/clip_fraction         | 0.0177       |
# |    gen/train/clip_range            | 0.2          |
# |    gen/train/entropy_loss          | -1.42        |
# |    gen/train/explained_variance    | -0.012       |
# |    gen/train/learning_rate         | 0.0004       |
# |    gen/train/loss                  | 0.139        |
# |    gen/train/n_updates             | 5            |
# |    gen/train/policy_gradient_loss  | -0.000286    |
# |    gen/train/std                   | 1.01         |
# |    gen/train/value_loss            | 5.45         |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.508    |
# |    disc/disc_acc_expert             | 0.0156   |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.689    |
# |    disc/disc_proportion_expert_pred | 0.00781  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.512    |
# |    disc/disc_acc_expert             | 0.0264   |
# |    disc/disc_acc_gen                | 0.998    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.686    |
# |    disc/disc_proportion_expert_pred | 0.0142   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.52     |
# |    disc/disc_acc_expert             | 0.0439   |
# |    disc/disc_acc_gen                | 0.995    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.684    |
# |    disc/disc_proportion_expert_pred | 0.0244   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.517    |
# |    disc/disc_acc_expert             | 0.042    |
# |    disc/disc_acc_gen                | 0.992    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.682    |
# |    disc/disc_proportion_expert_pred | 0.0249   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.522    |
# |    disc/disc_acc_expert             | 0.0674   |
# |    disc/disc_acc_gen                | 0.978    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.679    |
# |    disc/disc_proportion_expert_pred | 0.0449   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.525    |
# |    disc/disc_acc_expert             | 0.0771   |
# |    disc/disc_acc_gen                | 0.973    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.678    |
# |    disc/disc_proportion_expert_pred | 0.0522   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.528    |
# |    disc/disc_acc_expert             | 0.084    |
# |    disc/disc_acc_gen                | 0.973    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0.0557   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.546    |
# |    disc/disc_acc_expert             | 0.124    |
# |    disc/disc_acc_gen                | 0.968    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.67     |
# |    disc/disc_proportion_expert_pred | 0.0781   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.522     |
# |    disc/disc_acc_expert             | 0.0601    |
# |    disc/disc_acc_gen                | 0.984     |
# |    disc/disc_entropy                | 0.691     |
# |    disc/disc_loss                   | 0.68      |
# |    disc/disc_proportion_expert_pred | 0.0378    |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 2         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 200       |
# |    gen/rollout/ep_rew_mean          | -1.23e+03 |
# |    gen/rollout/ep_rew_wrapped_mean  | 131       |
# |    gen/time/fps                     | 6.18e+03  |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 2         |
# |    gen/time/total_timesteps         | 3.28e+04  |
# |    gen/train/approx_kl              | 0.00276   |
# |    gen/train/clip_fraction          | 0.0178    |
# |    gen/train/clip_range             | 0.2       |
# |    gen/train/entropy_loss           | -1.43     |
# |    gen/train/explained_variance     | -0.00838  |
# |    gen/train/learning_rate          | 0.0004    |
# |    gen/train/loss                   | 0.0869    |
# |    gen/train/n_updates              | 10        |
# |    gen/train/policy_gradient_loss   | -0.000509 |
# |    gen/train/std                    | 1.01      |
# |    gen/train/value_loss             | 0.356     |
# ---------------------------------------------------
# round:  17%|█▋        | 2/12 [00:11<00:59,  5.97s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 200          |
# |    gen/rollout/ep_rew_mean         | -1.25e+03    |
# |    gen/rollout/ep_rew_wrapped_mean | 128          |
# |    gen/time/fps                    | 6196         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 49152        |
# |    gen/train/approx_kl             | 0.0027575726 |
# |    gen/train/clip_fraction         | 0.0178       |
# |    gen/train/clip_range            | 0.2          |
# |    gen/train/entropy_loss          | -1.43        |
# |    gen/train/explained_variance    | -0.00838     |
# |    gen/train/learning_rate         | 0.0004       |
# |    gen/train/loss                  | 0.0869       |
# |    gen/train/n_updates             | 10           |
# |    gen/train/policy_gradient_loss  | -0.000509    |
# |    gen/train/std                   | 1.01         |
# |    gen/train/value_loss            | 0.356        |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.527    |
# |    disc/disc_acc_expert             | 0.117    |
# |    disc/disc_acc_gen                | 0.938    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.675    |
# |    disc/disc_proportion_expert_pred | 0.0898   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.531    |
# |    disc/disc_acc_expert             | 0.146    |
# |    disc/disc_acc_gen                | 0.916    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0.115    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.525    |
# |    disc/disc_acc_expert             | 0.144    |
# |    disc/disc_acc_gen                | 0.907    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0.118    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.521    |
# |    disc/disc_acc_expert             | 0.138    |
# |    disc/disc_acc_gen                | 0.903    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.668    |
# |    disc/disc_proportion_expert_pred | 0.117    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.535    |
# |    disc/disc_acc_expert             | 0.176    |
# |    disc/disc_acc_gen                | 0.894    |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.665    |
# |    disc/disc_proportion_expert_pred | 0.141    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.866    |
# |    disc/disc_acc_expert             | 0.85     |
# |    disc/disc_acc_gen                | 0.882    |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.661    |
# |    disc/disc_proportion_expert_pred | 0.484    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.872    |
# |    disc/disc_acc_expert             | 0.852    |
# |    disc/disc_acc_gen                | 0.892    |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.659    |
# |    disc/disc_proportion_expert_pred | 0.48     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.858    |
# |    disc/disc_acc_expert             | 0.843    |
# |    disc/disc_acc_gen                | 0.873    |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.657    |
# |    disc/disc_proportion_expert_pred | 0.485    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.654     |
# |    disc/disc_acc_expert             | 0.408     |
# |    disc/disc_acc_gen                | 0.901     |
# |    disc/disc_entropy                | 0.691     |
# |    disc/disc_loss                   | 0.666     |
# |    disc/disc_proportion_expert_pred | 0.254     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 3         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 200       |
# |    gen/rollout/ep_rew_mean          | -1.25e+03 |
# |    gen/rollout/ep_rew_wrapped_mean  | 128       |
# |    gen/time/fps                     | 6.2e+03   |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 2         |
# |    gen/time/total_timesteps         | 4.92e+04  |
# |    gen/train/approx_kl              | 0.0104    |
# |    gen/train/clip_fraction          | 0.116     |
# |    gen/train/clip_range             | 0.2       |
# |    gen/train/entropy_loss           | -1.4      |
# |    gen/train/explained_variance     | 0.195     |
# |    gen/train/learning_rate          | 0.0004    |
# |    gen/train/loss                   | 0.0212    |
# |    gen/train/n_updates              | 15        |
# |    gen/train/policy_gradient_loss   | -0.00974  |
# |    gen/train/std                    | 0.972     |
# |    gen/train/value_loss             | 0.0749    |
# ---------------------------------------------------
# round:  25%|██▌       | 3/12 [00:17<00:52,  5.87s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 200          |
# |    gen/rollout/ep_rew_mean         | -1.19e+03    |
# |    gen/rollout/ep_rew_wrapped_mean | 125          |
# |    gen/time/fps                    | 6192         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 65536        |
# |    gen/train/approx_kl             | 0.0104048215 |
# |    gen/train/clip_fraction         | 0.116        |
# |    gen/train/clip_range            | 0.2          |
# |    gen/train/entropy_loss          | -1.4         |
# |    gen/train/explained_variance    | 0.195        |
# |    gen/train/learning_rate         | 0.0004       |
# |    gen/train/loss                  | 0.0212       |
# |    gen/train/n_updates             | 15           |
# |    gen/train/policy_gradient_loss  | -0.00974     |
# |    gen/train/std                   | 0.972        |
# |    gen/train/value_loss            | 0.0749       |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.892    |
# |    disc/disc_acc_expert             | 0.836    |
# |    disc/disc_acc_gen                | 0.948    |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.651    |
# |    disc/disc_proportion_expert_pred | 0.444    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.893    |
# |    disc/disc_acc_expert             | 0.835    |
# |    disc/disc_acc_gen                | 0.951    |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0.442    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.884    |
# |    disc/disc_acc_expert             | 0.824    |
# |    disc/disc_acc_gen                | 0.943    |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.44     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.883    |
# |    disc/disc_acc_expert             | 0.816    |
# |    disc/disc_acc_gen                | 0.949    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0.434    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.895    |
# |    disc/disc_acc_expert             | 0.839    |
# |    disc/disc_acc_gen                | 0.95     |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.638    |
# |    disc/disc_proportion_expert_pred | 0.444    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.892    |
# |    disc/disc_acc_expert             | 0.841    |
# |    disc/disc_acc_gen                | 0.942    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.634    |
# |    disc/disc_proportion_expert_pred | 0.449    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.891    |
# |    disc/disc_acc_expert             | 0.85     |
# |    disc/disc_acc_gen                | 0.932    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.632    |
# |    disc/disc_proportion_expert_pred | 0.459    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.888    |
# |    disc/disc_acc_expert             | 0.828    |
# |    disc/disc_acc_gen                | 0.948    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.631    |
# |    disc/disc_proportion_expert_pred | 0.44     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.89      |
# |    disc/disc_acc_expert             | 0.834     |
# |    disc/disc_acc_gen                | 0.946     |
# |    disc/disc_entropy                | 0.688     |
# |    disc/disc_loss                   | 0.64      |
# |    disc/disc_proportion_expert_pred | 0.444     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 4         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 200       |
# |    gen/rollout/ep_rew_mean          | -1.19e+03 |
# |    gen/rollout/ep_rew_wrapped_mean  | 125       |
# |    gen/time/fps                     | 6.19e+03  |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 2         |
# |    gen/time/total_timesteps         | 6.55e+04  |
# |    gen/train/approx_kl              | 0.0147    |
# |    gen/train/clip_fraction          | 0.175     |
# |    gen/train/clip_range             | 0.2       |
# |    gen/train/entropy_loss           | -1.35     |
# |    gen/train/explained_variance     | 0.591     |
# |    gen/train/learning_rate          | 0.0004    |
# |    gen/train/loss                   | -0.0322   |
# |    gen/train/n_updates              | 20        |
# |    gen/train/policy_gradient_loss   | -0.0198   |
# |    gen/train/std                    | 0.929     |
# |    gen/train/value_loss             | 0.0293    |
# ---------------------------------------------------
# round:  33%|███▎      | 4/12 [00:23<00:46,  5.80s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_len_mean         | 200        |
# |    gen/rollout/ep_rew_mean         | -1.16e+03  |
# |    gen/rollout/ep_rew_wrapped_mean | 122        |
# |    gen/time/fps                    | 6130       |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 2          |
# |    gen/time/total_timesteps        | 81920      |
# |    gen/train/approx_kl             | 0.01466484 |
# |    gen/train/clip_fraction         | 0.175      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -1.35      |
# |    gen/train/explained_variance    | 0.591      |
# |    gen/train/learning_rate         | 0.0004     |
# |    gen/train/loss                  | -0.0322    |
# |    gen/train/n_updates             | 20         |
# |    gen/train/policy_gradient_loss  | -0.0198    |
# |    gen/train/std                   | 0.929      |
# |    gen/train/value_loss            | 0.0293     |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.829    |
# |    disc/disc_acc_expert             | 0.817    |
# |    disc/disc_acc_gen                | 0.841    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0.488    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.828    |
# |    disc/disc_acc_expert             | 0.838    |
# |    disc/disc_acc_gen                | 0.817    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.636    |
# |    disc/disc_proportion_expert_pred | 0.51     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.84     |
# |    disc/disc_acc_expert             | 0.845    |
# |    disc/disc_acc_gen                | 0.835    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.633    |
# |    disc/disc_proportion_expert_pred | 0.505    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.834    |
# |    disc/disc_acc_expert             | 0.839    |
# |    disc/disc_acc_gen                | 0.83     |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.632    |
# |    disc/disc_proportion_expert_pred | 0.504    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.828    |
# |    disc/disc_acc_expert             | 0.835    |
# |    disc/disc_acc_gen                | 0.82     |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.632    |
# |    disc/disc_proportion_expert_pred | 0.507    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.841    |
# |    disc/disc_acc_expert             | 0.844    |
# |    disc/disc_acc_gen                | 0.838    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.624    |
# |    disc/disc_proportion_expert_pred | 0.503    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.839    |
# |    disc/disc_acc_expert             | 0.847    |
# |    disc/disc_acc_gen                | 0.831    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.62     |
# |    disc/disc_proportion_expert_pred | 0.508    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.837    |
# |    disc/disc_acc_expert             | 0.841    |
# |    disc/disc_acc_gen                | 0.834    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.621    |
# |    disc/disc_proportion_expert_pred | 0.503    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.834     |
# |    disc/disc_acc_expert             | 0.838     |
# |    disc/disc_acc_gen                | 0.831     |
# |    disc/disc_entropy                | 0.685     |
# |    disc/disc_loss                   | 0.63      |
# |    disc/disc_proportion_expert_pred | 0.504     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 5         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 200       |
# |    gen/rollout/ep_rew_mean          | -1.16e+03 |
# |    gen/rollout/ep_rew_wrapped_mean  | 122       |
# |    gen/time/fps                     | 6.13e+03  |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 2         |
# |    gen/time/total_timesteps         | 8.19e+04  |
# |    gen/train/approx_kl              | 0.0138    |
# |    gen/train/clip_fraction          | 0.168     |
# |    gen/train/clip_range             | 0.2       |
# |    gen/train/entropy_loss           | -1.31     |
# |    gen/train/explained_variance     | 0.736     |
# |    gen/train/learning_rate          | 0.0004    |
# |    gen/train/loss                   | -0.00124  |
# |    gen/train/n_updates              | 25        |
# |    gen/train/policy_gradient_loss   | -0.019    |
# |    gen/train/std                    | 0.891     |
# |    gen/train/value_loss             | 0.0289    |
# ---------------------------------------------------
# round:  42%|████▏     | 5/12 [00:29<00:40,  5.77s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 200         |
# |    gen/rollout/ep_rew_mean         | -1.22e+03   |
# |    gen/rollout/ep_rew_wrapped_mean | 118         |
# |    gen/time/fps                    | 6170        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 98304       |
# |    gen/train/approx_kl             | 0.013843885 |
# |    gen/train/clip_fraction         | 0.168       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -1.31       |
# |    gen/train/explained_variance    | 0.736       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.00124    |
# |    gen/train/n_updates             | 25          |
# |    gen/train/policy_gradient_loss  | -0.019      |
# |    gen/train/std                   | 0.891       |
# |    gen/train/value_loss            | 0.0289      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.884    |
# |    disc/disc_acc_expert             | 0.854    |
# |    disc/disc_acc_gen                | 0.914    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.61     |
# |    disc/disc_proportion_expert_pred | 0.47     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.86     |
# |    disc/disc_acc_expert             | 0.818    |
# |    disc/disc_acc_gen                | 0.901    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.614    |
# |    disc/disc_proportion_expert_pred | 0.458    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.867    |
# |    disc/disc_acc_expert             | 0.832    |
# |    disc/disc_acc_gen                | 0.901    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.609    |
# |    disc/disc_proportion_expert_pred | 0.465    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.869    |
# |    disc/disc_acc_expert             | 0.83     |
# |    disc/disc_acc_gen                | 0.908    |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.603    |
# |    disc/disc_proportion_expert_pred | 0.461    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.868    |
# |    disc/disc_acc_expert             | 0.818    |
# |    disc/disc_acc_gen                | 0.917    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.603    |
# |    disc/disc_proportion_expert_pred | 0.451    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.882    |
# |    disc/disc_acc_expert             | 0.84     |
# |    disc/disc_acc_gen                | 0.925    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.596    |
# |    disc/disc_proportion_expert_pred | 0.458    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.881    |
# |    disc/disc_acc_expert             | 0.851    |
# |    disc/disc_acc_gen                | 0.912    |
# |    disc/disc_entropy                | 0.677    |
# |    disc/disc_loss                   | 0.588    |
# |    disc/disc_proportion_expert_pred | 0.469    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.88     |
# |    disc/disc_acc_expert             | 0.848    |
# |    disc/disc_acc_gen                | 0.913    |
# |    disc/disc_entropy                | 0.676    |
# |    disc/disc_loss                   | 0.586    |
# |    disc/disc_proportion_expert_pred | 0.467    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.874     |
# |    disc/disc_acc_expert             | 0.836     |
# |    disc/disc_acc_gen                | 0.911     |
# |    disc/disc_entropy                | 0.679     |
# |    disc/disc_loss                   | 0.601     |
# |    disc/disc_proportion_expert_pred | 0.462     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 6         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 200       |
# |    gen/rollout/ep_rew_mean          | -1.22e+03 |
# |    gen/rollout/ep_rew_wrapped_mean  | 118       |
# |    gen/time/fps                     | 6.17e+03  |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 2         |
# |    gen/time/total_timesteps         | 9.83e+04  |
# |    gen/train/approx_kl              | 0.016     |
# |    gen/train/clip_fraction          | 0.176     |
# |    gen/train/clip_range             | 0.2       |
# |    gen/train/entropy_loss           | -1.26     |
# |    gen/train/explained_variance     | 0.793     |
# |    gen/train/learning_rate          | 0.0004    |
# |    gen/train/loss                   | -0.022    |
# |    gen/train/n_updates              | 30        |
# |    gen/train/policy_gradient_loss   | -0.0179   |
# |    gen/train/std                    | 0.843     |
# |    gen/train/value_loss             | 0.0377    |
# ---------------------------------------------------
# round:  50%|█████     | 6/12 [00:34<00:34,  5.75s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 200         |
# ...
# |    gen/time/fps                    | 6232        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 180224      |
# |    gen/train/approx_kl             | 0.009474072 |
# |    gen/train/clip_fraction         | 0.117       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -1.11       |
# |    gen/train/explained_variance    | 0.902       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0945      |
# |    gen/train/n_updates             | 50          |
# |    gen/train/policy_gradient_loss  | -0.00852    |
# |    gen/train/std                   | 0.73        |
# |    gen/train/value_loss            | 0.182       |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.882    |
# |    disc/disc_acc_expert             | 0.86     |
# |    disc/disc_acc_gen                | 0.903    |
# |    disc/disc_entropy                | 0.581    |
# |    disc/disc_loss                   | 0.445    |
# |    disc/disc_proportion_expert_pred | 0.479    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.888    |
# |    disc/disc_acc_expert             | 0.862    |
# |    disc/disc_acc_gen                | 0.914    |
# |    disc/disc_entropy                | 0.578    |
# |    disc/disc_loss                   | 0.436    |
# |    disc/disc_proportion_expert_pred | 0.474    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.892    |
# |    disc/disc_acc_expert             | 0.875    |
# |    disc/disc_acc_gen                | 0.909    |
# |    disc/disc_entropy                | 0.577    |
# |    disc/disc_loss                   | 0.434    |
# |    disc/disc_proportion_expert_pred | 0.483    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.894    |
# |    disc/disc_acc_expert             | 0.858    |
# |    disc/disc_acc_gen                | 0.929    |
# |    disc/disc_entropy                | 0.57     |
# |    disc/disc_loss                   | 0.431    |
# |    disc/disc_proportion_expert_pred | 0.465    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.887    |
# |    disc/disc_acc_expert             | 0.866    |
# |    disc/disc_acc_gen                | 0.907    |
# |    disc/disc_entropy                | 0.565    |
# |    disc/disc_loss                   | 0.419    |
# |    disc/disc_proportion_expert_pred | 0.479    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.886    |
# |    disc/disc_acc_expert             | 0.86     |
# |    disc/disc_acc_gen                | 0.911    |
# |    disc/disc_entropy                | 0.566    |
# |    disc/disc_loss                   | 0.427    |
# |    disc/disc_proportion_expert_pred | 0.475    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.892    |
# |    disc/disc_acc_expert             | 0.863    |
# |    disc/disc_acc_gen                | 0.921    |
# |    disc/disc_entropy                | 0.557    |
# |    disc/disc_loss                   | 0.413    |
# |    disc/disc_proportion_expert_pred | 0.471    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.886    |
# |    disc/disc_acc_expert             | 0.854    |
# |    disc/disc_acc_gen                | 0.918    |
# |    disc/disc_entropy                | 0.554    |
# |    disc/disc_loss                   | 0.426    |
# |    disc/disc_proportion_expert_pred | 0.468    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.888     |
# |    disc/disc_acc_expert             | 0.863     |
# |    disc/disc_acc_gen                | 0.914     |
# |    disc/disc_entropy                | 0.568     |
# |    disc/disc_loss                   | 0.429     |
# |    disc/disc_proportion_expert_pred | 0.474     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 11        |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 200       |
# |    gen/rollout/ep_rew_mean          | -1.16e+03 |
# |    gen/rollout/ep_rew_wrapped_mean  | 82.6      |
# |    gen/time/fps                     | 6.23e+03  |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 2         |
# |    gen/time/total_timesteps         | 1.8e+05   |
# |    gen/train/approx_kl              | 0.00969   |
# |    gen/train/clip_fraction          | 0.113     |
# |    gen/train/clip_range             | 0.2       |
# |    gen/train/entropy_loss           | -1.08     |
# |    gen/train/explained_variance     | 0.934     |
# |    gen/train/learning_rate          | 0.0004    |
# |    gen/train/loss                   | 0.137     |
# |    gen/train/n_updates              | 55        |
# |    gen/train/policy_gradient_loss   | -0.00927  |
# |    gen/train/std                    | 0.71      |
# |    gen/train/value_loss             | 0.222     |
# ---------------------------------------------------
# round:  92%|█████████▏| 11/12 [01:06<00:06,  6.18s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 200         |
# |    gen/rollout/ep_rew_mean         | -1.1e+03    |
# |    gen/rollout/ep_rew_wrapped_mean | 78.4        |
# |    gen/time/fps                    | 6266        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 196608      |
# |    gen/train/approx_kl             | 0.009692896 |
# |    gen/train/clip_fraction         | 0.113       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -1.08       |
# |    gen/train/explained_variance    | 0.934       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.137       |
# |    gen/train/n_updates             | 55          |
# |    gen/train/policy_gradient_loss  | -0.00927    |
# |    gen/train/std                   | 0.71        |
# |    gen/train/value_loss            | 0.222       |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.884    |
# |    disc/disc_acc_expert             | 0.872    |
# |    disc/disc_acc_gen                | 0.896    |
# |    disc/disc_entropy                | 0.577    |
# |    disc/disc_loss                   | 0.445    |
# |    disc/disc_proportion_expert_pred | 0.488    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.876    |
# |    disc/disc_acc_expert             | 0.873    |
# |    disc/disc_acc_gen                | 0.879    |
# |    disc/disc_entropy                | 0.574    |
# |    disc/disc_loss                   | 0.439    |
# |    disc/disc_proportion_expert_pred | 0.497    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.863    |
# |    disc/disc_acc_expert             | 0.855    |
# |    disc/disc_acc_gen                | 0.871    |
# |    disc/disc_entropy                | 0.568    |
# |    disc/disc_loss                   | 0.447    |
# |    disc/disc_proportion_expert_pred | 0.492    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.877    |
# |    disc/disc_acc_expert             | 0.874    |
# |    disc/disc_acc_gen                | 0.881    |
# |    disc/disc_entropy                | 0.567    |
# |    disc/disc_loss                   | 0.431    |
# |    disc/disc_proportion_expert_pred | 0.497    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.861    |
# |    disc/disc_acc_expert             | 0.851    |
# |    disc/disc_acc_gen                | 0.872    |
# |    disc/disc_entropy                | 0.564    |
# |    disc/disc_loss                   | 0.451    |
# |    disc/disc_proportion_expert_pred | 0.489    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.886    |
# |    disc/disc_acc_expert             | 0.877    |
# |    disc/disc_acc_gen                | 0.896    |
# |    disc/disc_entropy                | 0.557    |
# |    disc/disc_loss                   | 0.429    |
# |    disc/disc_proportion_expert_pred | 0.491    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.869    |
# |    disc/disc_acc_expert             | 0.854    |
# |    disc/disc_acc_gen                | 0.884    |
# |    disc/disc_entropy                | 0.56     |
# |    disc/disc_loss                   | 0.436    |
# |    disc/disc_proportion_expert_pred | 0.485    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.86     |
# |    disc/disc_acc_expert             | 0.844    |
# |    disc/disc_acc_gen                | 0.877    |
# |    disc/disc_entropy                | 0.551    |
# |    disc/disc_loss                   | 0.445    |
# |    disc/disc_proportion_expert_pred | 0.483    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.872    |
# |    disc/disc_acc_expert             | 0.863    |
# |    disc/disc_acc_gen                | 0.882    |
# |    disc/disc_entropy                | 0.565    |
# |    disc/disc_loss                   | 0.44     |
# |    disc/disc_proportion_expert_pred | 0.49     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 200      |
# |    gen/rollout/ep_rew_mean          | -1.1e+03 |
# |    gen/rollout/ep_rew_wrapped_mean  | 78.4     |
# |    gen/time/fps                     | 6.27e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 1.97e+05 |
# |    gen/train/approx_kl              | 0.0123   |
# |    gen/train/clip_fraction          | 0.128    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -1.05    |
# |    gen/train/explained_variance     | 0.934    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.149    |
# |    gen/train/n_updates              | 60       |
# |    gen/train/policy_gradient_loss   | -0.0108  |
# |    gen/train/std                    | 0.69     |
# |    gen/train/value_loss             | 0.337    |
# --------------------------------------------------
# round: 100%|██████████| 12/12 [01:12<00:00,  6.01s/it]
# mean reward after training: -1027.2936809
# mean reward before training: -1208.5587643000001
